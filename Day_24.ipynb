# %%
# %%writefile atomicAddLL.cu
# Out:
# Overwriting atomicAddLL.cu

# %%
# %%writefile atomicAddLL.cu
# #include <stdio.h>
#
# __device__ long long atomicAddLL(long long *addr, long long val) {
#     unsigned long long *uaddr = (unsigned long long *)addr;
#     unsigned long long old = *uaddr, assumed;
#     do {
#         assumed = old;
#         old = atomicCAS(uaddr, assumed, assumed + val);
#     } while (assumed != old);
#     return (long long)old;
# }
#
# __global__ void atomicAddKernel(long long *data) {
#     int tid = threadIdx.x + blockIdx.x * blockDim.x;
#     printf("Thread %d adding value %d\n", tid, tid); // Added printf statement
#     atomicAddLL(data, tid);
# }
#
# int main() {
#     long long *d_data;
#     long long h_data = 0;
#
#     cudaMalloc(&d_data, sizeof(long long));
#     cudaMemcpy(d_data, &h_data, sizeof(long long), cudaMemcpyHostToDevice);
#
#     int threadsPerBlock = 256;
#     int blocksPerGrid = 4;
#
#     // Correct kernel launch
#     atomicAddKernel<<<blocksPerGrid, threadsPerBlock>>>(d_data);
#     cudaDeviceSynchronize();
#
#     cudaMemcpy(&h_data, d_data, sizeof(long long), cudaMemcpyDeviceToHost);
#     printf("Final value: %lld\n", h_data); // Expected: Sum of thread indices
#
#     cudaFree(d_data);
#     return 0;
# }
# Out:
# Overwriting atomicAddLL.cu

# %%
# !nvcc atomicAddLL.cu -o atomicAddLL -gencode arch=compute_75,code=sm_75 -lcublas

# !./atomicAddLL
# Out:
# Thread 576 adding value 576
# Thread 577 adding value 577
# Thread 578 adding value 578
# Thread 579 adding value 579
# Thread 580 adding value 580
# Thread 581 adding value 581
# Thread 582 adding value 582
# Thread 583 adding value 583
# Thread 584 adding value 584
# Thread 585 adding value 585
# Thread 586 adding value 586
# Thread 587 adding value 587
# Thread 588 adding value 588
# Thread 589 adding value 589
# Thread 590 adding value 590
# Thread 591 adding value 591
# Thread 592 adding value 592
# Thread 593 adding value 593
# Thread 594 adding value 594
# Thread 595 adding value 595
# Thread 596 adding value 596
# Thread 597 adding value 597
# Thread 598 adding value 598
# Thread 599 adding value 599
# Thread 600 adding value 600
# Thread 601 adding value 601
# Thread 602 adding value 602
# Thread 603 adding value 603
# Thread 604 adding value 604
# Thread 605 adding value 605
# Thread 606 adding value 606
# Thread 607 adding value 607
# Thread 672 adding value 672
# Thread 673 adding value 673
# Thread 674 adding value 674
# Thread 675 adding value 675
# Thread 676 adding value 676
# Thread 677 adding value 677
# Thread 678 adding value 678
# Thread 679 adding value 679
# Thread 680 adding value 680
# Thread 681 adding value 681
# Thread 682 adding value 682
# Thread 683 adding value 683
# Thread 684 adding value 684
# Thread 685 adding value 685
# Thread 686 adding value 686
# Thread 687 adding value 687
# Thread 688 adding value 688
# Thread 689 adding value 689
# Thread 690 adding value 690
# Thread 691 adding value 691
# Thread 692 adding value 692
# Thread 693 adding value 693
# Thread 694 adding value 694
# Thread 695 adding value 695
# Thread 696 adding value 696
# Thread 697 adding value 697
# Thread 698 adding value 698
# Thread 699 adding value 699
# Thread 700 adding value 700
# Thread 701 adding value 701
# Thread 702 adding value 702
# Thread 703 adding value 703
# Thread 736 adding value 736
# Thread 737 adding value 737
# Thread 738 adding value 738
# Thread 739 adding value 739
# Thread 740 adding value 740
# Thread 741 adding value 741
# Thread 742 adding value 742
# Thread 743 adding value 743
# Thread 744 adding value 744
# Thread 745 adding value 745
# Thread 746 adding value 746
# Thread 747 adding value 747
# Thread 748 adding value 748
# Thread 749 adding value 749
# Thread 750 adding value 750
# Thread 751 adding value 751
# Thread 752 adding value 752
# Thread 753 adding value 753
# Thread 754 adding value 754
# Thread 755 adding value 755
# Thread 756 adding value 756
# Thread 757 adding value 757
# Thread 758 adding value 758
# Thread 759 adding value 759
# Thread 760 adding value 760
# Thread 761 adding value 761
# Thread 762 adding value 762
# Thread 763 adding value 763
# Thread 764 adding value 764
# Thread 765 adding value 765
# Thread 766 adding value 766
# Thread 767 adding value 767
# Thread 544 adding value 544
# Thread 545 adding value 545
# Thread 546 adding value 546
# Thread 547 adding value 547
# Thread 548 adding value 548
# Thread 549 adding value 549
# Thread 550 adding value 550
# Thread 551 adding value 551
# Thread 552 adding value 552
# Thread 553 adding value 553
# Thread 554 adding value 554
# Thread 555 adding value 555
# Thread 556 adding value 556
# Thread 557 adding value 557
# Thread 558 adding value 558
# Thread 559 adding value 559
# Thread 560 adding value 560
# Thread 561 adding value 561
# Thread 562 adding value 562
# Thread 563 adding value 563
# Thread 564 adding value 564
# Thread 565 adding value 565
# Thread 566 adding value 566
# Thread 567 adding value 567
# Thread 568 adding value 568
# Thread 569 adding value 569
# Thread 570 adding value 570
# Thread 571 adding value 571
# Thread 572 adding value 572
# Thread 573 adding value 573
# Thread 574 adding value 574
# Thread 575 adding value 575
# Thread 704 adding value 704
# Thread 705 adding value 705
# Thread 706 adding value 706
# Thread 707 adding value 707
# Thread 708 adding value 708
# Thread 709 adding value 709
# Thread 710 adding value 710
# Thread 711 adding value 711
# Thread 712 adding value 712
# Thread 713 adding value 713
# Thread 714 adding value 714
# Thread 715 adding value 715
# Thread 716 adding value 716
# Thread 717 adding value 717
# Thread 718 adding value 718
# Thread 719 adding value 719
# Thread 720 adding value 720
# Thread 721 adding value 721
# Thread 722 adding value 722
# Thread 723 adding value 723
# Thread 724 adding value 724
# Thread 725 adding value 725
# Thread 726 adding value 726
# Thread 727 adding value 727
# Thread 728 adding value 728
# Thread 729 adding value 729
# Thread 730 adding value 730
# Thread 731 adding value 731
# Thread 732 adding value 732
# Thread 733 adding value 733
# Thread 734 adding value 734
# Thread 735 adding value 735
# Thread 608 adding value 608
# Thread 609 adding value 609
# Thread 610 adding value 610
# Thread 611 adding value 611
# Thread 612 adding value 612
# Thread 613 adding value 613
# Thread 614 adding value 614
# Thread 615 adding value 615
# Thread 616 adding value 616
# Thread 617 adding value 617
# Thread 618 adding value 618
# Thread 619 adding value 619
# Thread 620 adding value 620
# Thread 621 adding value 621
# Thread 622 adding value 622
# Thread 623 adding value 623
# Thread 624 adding value 624
# Thread 625 adding value 625
# Thread 626 adding value 626
# Thread 627 adding value 627
# Thread 628 adding value 628
# Thread 629 adding value 629
# Thread 630 adding value 630
# Thread 631 adding value 631
# Thread 632 adding value 632
# Thread 633 adding value 633
# Thread 634 adding value 634
# Thread 635 adding value 635
# Thread 636 adding value 636
# Thread 637 adding value 637
# Thread 638 adding value 638
# Thread 639 adding value 639
# Thread 640 adding value 640
# Thread 641 adding value 641
# Thread 642 adding value 642
# Thread 643 adding value 643
# Thread 644 adding value 644
# Thread 645 adding value 645
# Thread 646 adding value 646
# Thread 647 adding value 647
# Thread 648 adding value 648
# Thread 649 adding value 649
# Thread 650 adding value 650
# Thread 651 adding value 651
# Thread 652 adding value 652
# Thread 653 adding value 653
# Thread 654 adding value 654
# Thread 655 adding value 655
# Thread 656 adding value 656
# Thread 657 adding value 657
# Thread 658 adding value 658
# Thread 659 adding value 659
# Thread 660 adding value 660
# Thread 661 adding value 661
# Thread 662 adding value 662
# Thread 663 adding value 663
# Thread 664 adding value 664
# Thread 665 adding value 665
# Thread 666 adding value 666
# Thread 667 adding value 667
# Thread 668 adding value 668
# Thread 669 adding value 669
# Thread 670 adding value 670
# Thread 671 adding value 671
# Thread 512 adding value 512
# Thread 513 adding value 513
# Thread 514 adding value 514
# Thread 515 adding value 515
# Thread 516 adding value 516
# Thread 517 adding value 517
# Thread 518 adding value 518
# Thread 519 adding value 519
# Thread 520 adding value 520
# Thread 521 adding value 521
# Thread 522 adding value 522
# Thread 523 adding value 523
# Thread 524 adding value 524
# Thread 525 adding value 525
# Thread 526 adding value 526
# Thread 527 adding value 527
# Thread 528 adding value 528
# Thread 529 adding value 529
# Thread 530 adding value 530
# Thread 531 adding value 531
# Thread 532 adding value 532
# Thread 533 adding value 533
# Thread 534 adding value 534
# Thread 535 adding value 535
# Thread 536 adding value 536
# Thread 537 adding value 537
# Thread 538 adding value 538
# Thread 539 adding value 539
# Thread 540 adding value 540
# Thread 541 adding value 541
# Thread 542 adding value 542
# Thread 543 adding value 543
# Thread 32 adding value 32
# Thread 33 adding value 33
# Thread 34 adding value 34
# Thread 35 adding value 35
# Thread 36 adding value 36
# Thread 37 adding value 37
# Thread 38 adding value 38
# Thread 39 adding value 39
# Thread 40 adding value 40
# Thread 41 adding value 41
# Thread 42 adding value 42
# Thread 43 adding value 43
# Thread 44 adding value 44
# Thread 45 adding value 45
# Thread 46 adding value 46
# Thread 47 adding value 47
# Thread 48 adding value 48
# Thread 49 adding value 49
# Thread 50 adding value 50
# Thread 51 adding value 51
# Thread 52 adding value 52
# Thread 53 adding value 53
# Thread 54 adding value 54
# Thread 55 adding value 55
# Thread 56 adding value 56
# Thread 57 adding value 57
# Thread 58 adding value 58
# Thread 59 adding value 59
# Thread 60 adding value 60
# Thread 61 adding value 61
# Thread 62 adding value 62
# Thread 63 adding value 63
# Thread 160 adding value 160
# Thread 161 adding value 161
# Thread 162 adding value 162
# Thread 163 adding value 163
# Thread 164 adding value 164
# Thread 165 adding value 165
# Thread 166 adding value 166
# Thread 167 adding value 167
# Thread 168 adding value 168
# Thread 169 adding value 169
# Thread 170 adding value 170
# Thread 171 adding value 171
# Thread 172 adding value 172
# Thread 173 adding value 173
# Thread 174 adding value 174
# Thread 175 adding value 175
# Thread 176 adding value 176
# Thread 177 adding value 177
# Thread 178 adding value 178
# Thread 179 adding value 179
# Thread 180 adding value 180
# Thread 181 adding value 181
# Thread 182 adding value 182
# Thread 183 adding value 183
# Thread 184 adding value 184
# Thread 185 adding value 185
# Thread 186 adding value 186
# Thread 187 adding value 187
# Thread 188 adding value 188
# Thread 189 adding value 189
# Thread 190 adding value 190
# Thread 191 adding value 191
# Thread 192 adding value 192
# Thread 193 adding value 193
# Thread 194 adding value 194
# Thread 195 adding value 195
# Thread 196 adding value 196
# Thread 197 adding value 197
# Thread 198 adding value 198
# Thread 199 adding value 199
# Thread 200 adding value 200
# Thread 201 adding value 201
# Thread 202 adding value 202
# Thread 203 adding value 203
# Thread 204 adding value 204
# Thread 205 adding value 205
# Thread 206 adding value 206
# Thread 207 adding value 207
# Thread 208 adding value 208
# Thread 209 adding value 209
# Thread 210 adding value 210
# Thread 211 adding value 211
# Thread 212 adding value 212
# Thread 213 adding value 213
# Thread 214 adding value 214
# Thread 215 adding value 215
# Thread 216 adding value 216
# Thread 217 adding value 217
# Thread 218 adding value 218
# Thread 219 adding value 219
# Thread 220 adding value 220
# Thread 221 adding value 221
# Thread 222 adding value 222
# Thread 223 adding value 223
# Thread 96 adding value 96
# Thread 97 adding value 97
# Thread 98 adding value 98
# Thread 99 adding value 99
# Thread 100 adding value 100
# Thread 101 adding value 101
# Thread 102 adding value 102
# Thread 103 adding value 103
# Thread 104 adding value 104
# Thread 105 adding value 105
# Thread 106 adding value 106
# Thread 107 adding value 107
# Thread 108 adding value 108
# Thread 109 adding value 109
# Thread 110 adding value 110
# Thread 111 adding value 111
# Thread 112 adding value 112
# Thread 113 adding value 113
# Thread 114 adding value 114
# Thread 115 adding value 115
# Thread 116 adding value 116
# Thread 117 adding value 117
# Thread 118 adding value 118
# Thread 119 adding value 119
# Thread 120 adding value 120
# Thread 121 adding value 121
# Thread 122 adding value 122
# Thread 123 adding value 123
# Thread 124 adding value 124
# Thread 125 adding value 125
# Thread 126 adding value 126
# Thread 127 adding value 127
# Thread 224 adding value 224
# Thread 225 adding value 225
# Thread 226 adding value 226
# Thread 227 adding value 227
# Thread 228 adding value 228
# Thread 229 adding value 229
# Thread 230 adding value 230
# Thread 231 adding value 231
# Thread 232 adding value 232
# Thread 233 adding value 233
# Thread 234 adding value 234
# Thread 235 adding value 235
# Thread 236 adding value 236
# Thread 237 adding value 237
# Thread 238 adding value 238
# Thread 239 adding value 239
# Thread 240 adding value 240
# Thread 241 adding value 241
# Thread 242 adding value 242
# Thread 243 adding value 243
# Thread 244 adding value 244
# Thread 245 adding value 245
# Thread 246 adding value 246
# Thread 247 adding value 247
# Thread 248 adding value 248
# Thread 249 adding value 249
# Thread 250 adding value 250
# Thread 251 adding value 251
# Thread 252 adding value 252
# Thread 253 adding value 253
# Thread 254 adding value 254
# Thread 255 adding value 255
# Thread 128 adding value 128
# Thread 129 adding value 129
# Thread 130 adding value 130
# Thread 131 adding value 131
# Thread 132 adding value 132
# Thread 133 adding value 133
# Thread 134 adding value 134
# Thread 135 adding value 135
# Thread 136 adding value 136
# Thread 137 adding value 137
# Thread 138 adding value 138
# Thread 139 adding value 139
# Thread 140 adding value 140
# Thread 141 adding value 141
# Thread 142 adding value 142
# Thread 143 adding value 143
# Thread 144 adding value 144
# Thread 145 adding value 145
# Thread 146 adding value 146
# Thread 147 adding value 147
# Thread 148 adding value 148
# Thread 149 adding value 149
# Thread 150 adding value 150
# Thread 151 adding value 151
# Thread 152 adding value 152
# Thread 153 adding value 153
# Thread 154 adding value 154
# Thread 155 adding value 155
# Thread 156 adding value 156
# Thread 157 adding value 157
# Thread 158 adding value 158
# Thread 159 adding value 159
# Thread 0 adding value 0
# Thread 1 adding value 1
# Thread 2 adding value 2
# Thread 3 adding value 3
# Thread 4 adding value 4
# Thread 5 adding value 5
# Thread 6 adding value 6
# Thread 7 adding value 7
# Thread 8 adding value 8
# Thread 9 adding value 9
# Thread 10 adding value 10
# Thread 11 adding value 11
# Thread 12 adding value 12
# Thread 13 adding value 13
# Thread 14 adding value 14
# Thread 15 adding value 15
# Thread 16 adding value 16
# Thread 17 adding value 17
# Thread 18 adding value 18
# Thread 19 adding value 19
# Thread 20 adding value 20
# Thread 21 adding value 21
# Thread 22 adding value 22
# Thread 23 adding value 23
# Thread 24 adding value 24
# Thread 25 adding value 25
# Thread 26 adding value 26
# Thread 27 adding value 27
# Thread 28 adding value 28
# Thread 29 adding value 29
# Thread 30 adding value 30
# Thread 31 adding value 31
# Thread 448 adding value 448
# Thread 449 adding value 449
# Thread 450 adding value 450
# Thread 451 adding value 451
# Thread 452 adding value 452
# Thread 453 adding value 453
# Thread 454 adding value 454
# Thread 455 adding value 455
# Thread 456 adding value 456
# Thread 457 adding value 457
# Thread 458 adding value 458
# Thread 459 adding value 459
# Thread 460 adding value 460
# Thread 461 adding value 461
# Thread 462 adding value 462
# Thread 463 adding value 463
# Thread 464 adding value 464
# Thread 465 adding value 465
# Thread 466 adding value 466
# Thread 467 adding value 467
# Thread 468 adding value 468
# Thread 469 adding value 469
# Thread 470 adding value 470
# Thread 471 adding value 471
# Thread 472 adding value 472
# Thread 473 adding value 473
# Thread 474 adding value 474
# Thread 475 adding value 475
# Thread 476 adding value 476
# Thread 477 adding value 477
# Thread 478 adding value 478
# Thread 479 adding value 479
# Thread 480 adding value 480
# Thread 481 adding value 481
# Thread 482 adding value 482
# Thread 483 adding value 483
# Thread 484 adding value 484
# Thread 485 adding value 485
# Thread 486 adding value 486
# Thread 487 adding value 487
# Thread 488 adding value 488
# Thread 489 adding value 489
# Thread 490 adding value 490
# Thread 491 adding value 491
# Thread 492 adding value 492
# Thread 493 adding value 493
# Thread 494 adding value 494
# Thread 495 adding value 495
# Thread 496 adding value 496
# Thread 497 adding value 497
# Thread 498 adding value 498
# Thread 499 adding value 499
# Thread 500 adding value 500
# Thread 501 adding value 501
# Thread 502 adding value 502
# Thread 503 adding value 503
# Thread 504 adding value 504
# Thread 505 adding value 505
# Thread 506 adding value 506
# Thread 507 adding value 507
# Thread 508 adding value 508
# Thread 509 adding value 509
# Thread 510 adding value 510
# Thread 511 adding value 511
# Thread 896 adding value 896
# Thread 897 adding value 897
# Thread 898 adding value 898
# Thread 899 adding value 899
# Thread 900 adding value 900
# Thread 901 adding value 901
# Thread 902 adding value 902
# Thread 903 adding value 903
# Thread 904 adding value 904
# Thread 905 adding value 905
# Thread 906 adding value 906
# Thread 907 adding value 907
# Thread 908 adding value 908
# Thread 909 adding value 909
# Thread 910 adding value 910
# Thread 911 adding value 911
# Thread 912 adding value 912
# Thread 913 adding value 913
# Thread 914 adding value 914
# Thread 915 adding value 915
# Thread 916 adding value 916
# Thread 917 adding value 917
# Thread 918 adding value 918
# Thread 919 adding value 919
# Thread 920 adding value 920
# Thread 921 adding value 921
# Thread 922 adding value 922
# Thread 923 adding value 923
# Thread 924 adding value 924
# Thread 925 adding value 925
# Thread 926 adding value 926
# Thread 927 adding value 927
# Thread 928 adding value 928
# Thread 929 adding value 929
# Thread 930 adding value 930
# Thread 931 adding value 931
# Thread 932 adding value 932
# Thread 933 adding value 933
# Thread 934 adding value 934
# Thread 935 adding value 935
# Thread 936 adding value 936
# Thread 937 adding value 937
# Thread 938 adding value 938
# Thread 939 adding value 939
# Thread 940 adding value 940
# Thread 941 adding value 941
# Thread 942 adding value 942
# Thread 943 adding value 943
# Thread 944 adding value 944
# Thread 945 adding value 945
# Thread 946 adding value 946
# Thread 947 adding value 947
# Thread 948 adding value 948
# Thread 949 adding value 949
# Thread 950 adding value 950
# Thread 951 adding value 951
# Thread 952 adding value 952
# Thread 953 adding value 953
# Thread 954 adding value 954
# Thread 955 adding value 955
# Thread 956 adding value 956
# Thread 957 adding value 957
# Thread 958 adding value 958
# Thread 959 adding value 959
# Thread 960 adding value 960
# Thread 961 adding value 961
# Thread 962 adding value 962
# Thread 963 adding value 963
# Thread 964 adding value 964
# Thread 965 adding value 965
# Thread 966 adding value 966
# Thread 967 adding value 967
# Thread 968 adding value 968
# Thread 969 adding value 969
# Thread 970 adding value 970
# Thread 971 adding value 971
# Thread 972 adding value 972
# Thread 973 adding value 973
# Thread 974 adding value 974
# Thread 975 adding value 975
# Thread 976 adding value 976
# Thread 977 adding value 977
# Thread 978 adding value 978
# Thread 979 adding value 979
# Thread 980 adding value 980
# Thread 981 adding value 981
# Thread 982 adding value 982
# Thread 983 adding value 983
# Thread 984 adding value 984
# Thread 985 adding value 985
# Thread 986 adding value 986
# Thread 987 adding value 987
# Thread 988 adding value 988
# Thread 989 adding value 989
# Thread 990 adding value 990
# Thread 991 adding value 991
# Thread 416 adding value 416
# Thread 417 adding value 417
# Thread 418 adding value 418
# Thread 419 adding value 419
# Thread 420 adding value 420
# Thread 421 adding value 421
# Thread 422 adding value 422
# Thread 423 adding value 423
# Thread 424 adding value 424
# Thread 425 adding value 425
# Thread 426 adding value 426
# Thread 427 adding value 427
# Thread 428 adding value 428
# Thread 429 adding value 429
# Thread 430 adding value 430
# Thread 431 adding value 431
# Thread 432 adding value 432
# Thread 433 adding value 433
# Thread 434 adding value 434
# Thread 435 adding value 435
# Thread 436 adding value 436
# Thread 437 adding value 437
# Thread 438 adding value 438
# Thread 439 adding value 439
# Thread 440 adding value 440
# Thread 441 adding value 441
# Thread 442 adding value 442
# Thread 443 adding value 443
# Thread 444 adding value 444
# Thread 445 adding value 445
# Thread 446 adding value 446
# Thread 447 adding value 447
# Thread 320 adding value 320
# Thread 321 adding value 321
# Thread 322 adding value 322
# Thread 323 adding value 323
# Thread 324 adding value 324
# Thread 325 adding value 325
# Thread 326 adding value 326
# Thread 327 adding value 327
# Thread 328 adding value 328
# Thread 329 adding value 329
# Thread 330 adding value 330
# Thread 331 adding value 331
# Thread 332 adding value 332
# Thread 333 adding value 333
# Thread 334 adding value 334
# Thread 335 adding value 335
# Thread 336 adding value 336
# Thread 337 adding value 337
# Thread 338 adding value 338
# Thread 339 adding value 339
# Thread 340 adding value 340
# Thread 341 adding value 341
# Thread 342 adding value 342
# Thread 343 adding value 343
# Thread 344 adding value 344
# Thread 345 adding value 345
# Thread 346 adding value 346
# Thread 347 adding value 347
# Thread 348 adding value 348
# Thread 349 adding value 349
# Thread 350 adding value 350
# Thread 351 adding value 351
# Thread 256 adding value 256
# Thread 257 adding value 257
# Thread 258 adding value 258
# Thread 259 adding value 259
# Thread 260 adding value 260
# Thread 261 adding value 261
# Thread 262 adding value 262
# Thread 263 adding value 263
# Thread 264 adding value 264
# Thread 265 adding value 265
# Thread 266 adding value 266
# Thread 267 adding value 267
# Thread 268 adding value 268
# Thread 269 adding value 269
# Thread 270 adding value 270
# Thread 271 adding value 271
# Thread 272 adding value 272
# Thread 273 adding value 273
# Thread 274 adding value 274
# Thread 275 adding value 275
# Thread 276 adding value 276
# Thread 277 adding value 277
# Thread 278 adding value 278
# Thread 279 adding value 279
# Thread 280 adding value 280
# Thread 281 adding value 281
# Thread 282 adding value 282
# Thread 283 adding value 283
# Thread 284 adding value 284
# Thread 285 adding value 285
# Thread 286 adding value 286
# Thread 287 adding value 287
# Thread 768 adding value 768
# Thread 769 adding value 769
# Thread 770 adding value 770
# Thread 771 adding value 771
# Thread 772 adding value 772
# Thread 773 adding value 773
# Thread 774 adding value 774
# Thread 775 adding value 775
# Thread 776 adding value 776
# Thread 777 adding value 777
# Thread 778 adding value 778
# Thread 779 adding value 779
# Thread 780 adding value 780
# Thread 781 adding value 781
# Thread 782 adding value 782
# Thread 783 adding value 783
# Thread 784 adding value 784
# Thread 785 adding value 785
# Thread 786 adding value 786
# Thread 787 adding value 787
# Thread 788 adding value 788
# Thread 789 adding value 789
# Thread 790 adding value 790
# Thread 791 adding value 791
# Thread 792 adding value 792
# Thread 793 adding value 793
# Thread 794 adding value 794
# Thread 795 adding value 795
# Thread 796 adding value 796
# Thread 797 adding value 797
# Thread 798 adding value 798
# Thread 799 adding value 799
# Thread 352 adding value 352
# Thread 353 adding value 353
# Thread 354 adding value 354
# Thread 355 adding value 355
# Thread 356 adding value 356
# Thread 357 adding value 357
# Thread 358 adding value 358
# Thread 359 adding value 359
# Thread 360 adding value 360
# Thread 361 adding value 361
# Thread 362 adding value 362
# Thread 363 adding value 363
# Thread 364 adding value 364
# Thread 365 adding value 365
# Thread 366 adding value 366
# Thread 367 adding value 367
# Thread 368 adding value 368
# Thread 369 adding value 369
# Thread 370 adding value 370
# Thread 371 adding value 371
# Thread 372 adding value 372
# Thread 373 adding value 373
# Thread 374 adding value 374
# Thread 375 adding value 375
# Thread 376 adding value 376
# Thread 377 adding value 377
# Thread 378 adding value 378
# Thread 379 adding value 379
# Thread 380 adding value 380
# Thread 381 adding value 381
# Thread 382 adding value 382
# Thread 383 adding value 383
# Thread 384 adding value 384
# Thread 385 adding value 385
# Thread 386 adding value 386
# Thread 387 adding value 387
# Thread 388 adding value 388
# Thread 389 adding value 389
# Thread 390 adding value 390
# Thread 391 adding value 391
# Thread 392 adding value 392
# Thread 393 adding value 393
# Thread 394 adding value 394
# Thread 395 adding value 395
# Thread 396 adding value 396
# Thread 397 adding value 397
# Thread 398 adding value 398
# Thread 399 adding value 399
# Thread 400 adding value 400
# Thread 401 adding value 401
# Thread 402 adding value 402
# Thread 403 adding value 403
# Thread 404 adding value 404
# Thread 405 adding value 405
# Thread 406 adding value 406
# Thread 407 adding value 407
# Thread 408 adding value 408
# Thread 409 adding value 409
# Thread 410 adding value 410
# Thread 411 adding value 411
# Thread 412 adding value 412
# Thread 413 adding value 413
# Thread 414 adding value 414
# Thread 415 adding value 415
# Thread 288 adding value 288
# Thread 289 adding value 289
# Thread 290 adding value 290
# Thread 291 adding value 291
# Thread 292 adding value 292
# Thread 293 adding value 293
# Thread 294 adding value 294
# Thread 295 adding value 295
# Thread 296 adding value 296
# Thread 297 adding value 297
# Thread 298 adding value 298
# Thread 299 adding value 299
# Thread 300 adding value 300
# Thread 301 adding value 301
# Thread 302 adding value 302
# Thread 303 adding value 303
# Thread 304 adding value 304
# Thread 305 adding value 305
# Thread 306 adding value 306
# Thread 307 adding value 307
# Thread 308 adding value 308
# Thread 309 adding value 309
# Thread 310 adding value 310
# Thread 311 adding value 311
# Thread 312 adding value 312
# Thread 313 adding value 313
# Thread 314 adding value 314
# Thread 315 adding value 315
# Thread 316 adding value 316
# Thread 317 adding value 317
# Thread 318 adding value 318
# Thread 319 adding value 319
# Thread 800 adding value 800
# Thread 801 adding value 801
# Thread 802 adding value 802
# Thread 803 adding value 803
# Thread 804 adding value 804
# Thread 805 adding value 805
# Thread 806 adding value 806
# Thread 807 adding value 807
# Thread 808 adding value 808
# Thread 809 adding value 809
# Thread 810 adding value 810
# Thread 811 adding value 811
# Thread 812 adding value 812
# Thread 813 adding value 813
# Thread 814 adding value 814
# Thread 815 adding value 815
# Thread 816 adding value 816
# Thread 817 adding value 817
# Thread 818 adding value 818
# Thread 819 adding value 819
# Thread 820 adding value 820
# Thread 821 adding value 821
# Thread 822 adding value 822
# Thread 823 adding value 823
# Thread 824 adding value 824
# Thread 825 adding value 825
# Thread 826 adding value 826
# Thread 827 adding value 827
# Thread 828 adding value 828
# Thread 829 adding value 829
# Thread 830 adding value 830
# Thread 831 adding value 831
# Thread 832 adding value 832
# Thread 833 adding value 833
# Thread 834 adding value 834
# Thread 835 adding value 835
# Thread 836 adding value 836
# Thread 837 adding value 837
# Thread 838 adding value 838
# Thread 839 adding value 839
# Thread 840 adding value 840
# Thread 841 adding value 841
# Thread 842 adding value 842
# Thread 843 adding value 843
# Thread 844 adding value 844
# Thread 845 adding value 845
# Thread 846 adding value 846
# Thread 847 adding value 847
# Thread 848 adding value 848
# Thread 849 adding value 849
# Thread 850 adding value 850
# Thread 851 adding value 851
# Thread 852 adding value 852
# Thread 853 adding value 853
# Thread 854 adding value 854
# Thread 855 adding value 855
# Thread 856 adding value 856
# Thread 857 adding value 857
# Thread 858 adding value 858
# Thread 859 adding value 859
# Thread 860 adding value 860
# Thread 861 adding value 861
# Thread 862 adding value 862
# Thread 863 adding value 863
# Thread 64 adding value 64
# Thread 65 adding value 65
# Thread 66 adding value 66
# Thread 67 adding value 67
# Thread 68 adding value 68
# Thread 69 adding value 69
# Thread 70 adding value 70
# Thread 71 adding value 71
# Thread 72 adding value 72
# Thread 73 adding value 73
# Thread 74 adding value 74
# Thread 75 adding value 75
# Thread 76 adding value 76
# Thread 77 adding value 77
# Thread 78 adding value 78
# Thread 79 adding value 79
# Thread 80 adding value 80
# Thread 81 adding value 81
# Thread 82 adding value 82
# Thread 83 adding value 83
# Thread 84 adding value 84
# Thread 85 adding value 85
# Thread 86 adding value 86
# Thread 87 adding value 87
# Thread 88 adding value 88
# Thread 89 adding value 89
# Thread 90 adding value 90
# Thread 91 adding value 91
# Thread 92 adding value 92
# Thread 93 adding value 93
# Thread 94 adding value 94
# Thread 95 adding value 95
# Thread 864 adding value 864
# Thread 865 adding value 865
# Thread 866 adding value 866
# Thread 867 adding value 867
# Thread 868 adding value 868
# Thread 869 adding value 869
# Thread 870 adding value 870
# Thread 871 adding value 871
# Thread 872 adding value 872
# Thread 873 adding value 873
# Thread 874 adding value 874
# Thread 875 adding value 875
# Thread 876 adding value 876
# Thread 877 adding value 877
# Thread 878 adding value 878
# Thread 879 adding value 879
# Thread 880 adding value 880
# Thread 881 adding value 881
# Thread 882 adding value 882
# Thread 883 adding value 883
# Thread 884 adding value 884
# Thread 885 adding value 885
# Thread 886 adding value 886
# Thread 887 adding value 887
# Thread 888 adding value 888
# Thread 889 adding value 889
# Thread 890 adding value 890
# Thread 891 adding value 891
# Thread 892 adding value 892
# Thread 893 adding value 893
# Thread 894 adding value 894
# Thread 895 adding value 895
# Thread 992 adding value 992
# Thread 993 adding value 993
# Thread 994 adding value 994
# Thread 995 adding value 995
# Thread 996 adding value 996
# Thread 997 adding value 997
# Thread 998 adding value 998
# Thread 999 adding value 999
# Thread 1000 adding value 1000
# Thread 1001 adding value 1001
# Thread 1002 adding value 1002
# Thread 1003 adding value 1003
# Thread 1004 adding value 1004
# Thread 1005 adding value 1005
# Thread 1006 adding value 1006
# Thread 1007 adding value 1007
# Thread 1008 adding value 1008
# Thread 1009 adding value 1009
# Thread 1010 adding value 1010
# Thread 1011 adding value 1011
# Thread 1012 adding value 1012
# Thread 1013 adding value 1013
# Thread 1014 adding value 1014
# Thread 1015 adding value 1015
# Thread 1016 adding value 1016
# Thread 1017 adding value 1017
# Thread 1018 adding value 1018
# Thread 1019 adding value 1019
# Thread 1020 adding value 1020
# Thread 1021 adding value 1021
# Thread 1022 adding value 1022
# Thread 1023 adding value 1023
# Final value: 523776
